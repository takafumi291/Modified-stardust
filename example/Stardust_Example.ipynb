# %% [markdown]
# # Example: Fit Catalogue with Stardust

# %%
import stardust
import numpy as np
# Out:
# Imported filters from filters/filters.txt

# %% [markdown]
# Load in the class by proving the path to the .config file.

# %%
self = stardust.main.ctf(config_file='example.config')
# Out:
# READ CONFIG FILE example.config
# Read a catalogue with 300 objects
# Read band file: stellar+ir/example.bands
# Read param file: stellar+ir/example.param
# Using Legacy Format
# Detected the following parameters ['ID', 'z', 'Mstar']
# Input Bands: ok
# Input Filters: ok
# Data Loaded Successfully
# Objects to Fit: 300
# /Users/takafumi/miniconda3/envs/py39/lib/python3.9/site-packages/stardust/main.py:409: RuntimeWarning: invalid value encountered in divide
#   sn = self.fnu[i]/self.efnu[i]

# %% [markdown]
# We can double check what parameters are in the config file

# %%
self.config
# Out:
# {'CATALOGUE': 'stellar+ir/c2015_sdc2_example.fits',
#  'BANDS_FILE': 'stellar+ir/example.bands',
#  'EXTRA_BANDS_FILE': 'None',
#  'PARAM_FILE': 'stellar+ir/example.param',
#  'PATH': 'test/output/',
#  'OUTPUT_NAME': 'test',
#  'SAVE_FIGURE': 0.0,
#  'SAVE_TABLE': 0.0,
#  'SAVE_SED': 0.0,
#  'SAVE_COVAR': 0.0,
#  'VERBOSE': 1.0,
#  'FLUX_UNIT': 'mJy',
#  'EXTRA_BANDS': 0.0,
#  'AGN_EXTRA_BANDS': 0.0,
#  'USE_COLD_DL': 1.0,
#  'RADIO_METHOD': 'delv20',
#  'UNCERT_SCALE': 0.05,
#  'QSO': 0.0,
#  'IGM_SWITCH': 0.0,
#  'USE_OWN_STELLAR_MASS': 'False',
#  'ABZP': 23.9,
#  'FIT_DUST': 1.0,
#  'FIT_AGN': 1.0,
#  'FIT_STELLAR': 1.0}

# %% [markdown]
# These can also be changed manually after loading the module e.g.

# %%
self.config['OUTPUT_NAME'] = 'example_name'

# %% [markdown]
# Fit a single object from the catalogue and show its SED

# %%
idx = 0
self.fit_object(idx)
self.show_fit(idx,radio=True)
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  {'lambda': array([3.87860211e-02, 4.00646811e-02, 4.09171211e-02, ...,
#          1.14531979e+06, 1.24245395e+06, 1.34782602e+06]),
#   'templ_optical': array([1.11291795e-47, 1.20039935e-43, 3.52332892e-41, ...,
#          2.48621282e-09, 2.26362765e-09, 2.06141711e-09]),
#   'templ_agn': array([0., 0., 0., ..., 0., 0., 0.]),
#   'templ_ir': array([2.70798194e-52, 5.77603070e-52, 9.44429405e-52, ...,
#          5.38044061e-09, 4.24262812e-09, 3.34543110e-09]),
#   'pivot': array([2.15030000e+00, 1.02170000e+00, 1.64330000e+00, 1.25270000e+00,
#          4.44800000e-01, 5.47020000e-01, 7.67120000e-01, 6.27550000e-01,
#          3.83790000e-01, 9.02820000e-01, 4.84730000e-01, 5.25930000e-01,
#          6.23080000e-01, 6.78160000e-01, 7.35950000e-01, 4.26000000e-01,
#          4.63330000e-01, 5.06080000e-01, 5.76290000e-01, 7.07350000e-01,
#          8.24680000e-01, 7.12020000e-01, 8.15090000e-01, 3.55690000e+00,
#          4.50200000e+00, 5.74500000e+00, 7.91580000e+00, 2.37589000e+01,
#          1.02007000e+02, 1.65356000e+02, 2.50429000e+02, 3.51368000e+02,
#          5.07844000e+02, 8.54354497e+02, 3.54017000e-01, 9.02470000e-01]),
#   'fobs': array([ 8.91051802e-04,  8.88778521e-05,  3.02724751e-04, -9.90000000e+01,
#           5.83924843e-05,  4.22279591e-05,  1.16015606e-04,  1.17852854e-04,
#           2.15326493e-05,  1.25498701e-04,  9.50179472e-05,  3.45593746e-05,
#           1.72644423e-04,  1.96902249e-05,  2.02836035e-04, -9.90000000e+01,
#           1.30382329e-04,  5.28255115e-05,  1.01973953e-04,  1.05050917e-04,
#           2.09411129e-04,  2.13695759e-04,  4.86797044e-05,  2.83332750e-03,
#           5.31374900e-03,  1.00597070e-02,  5.23504100e-03,  1.14791000e-01,
#           5.27326240e+00,  3.68549440e+00,  6.46488000e+00,  8.20969000e+00,
#           1.22473000e+01,  3.85360800e+00, -9.90000000e+01, -9.90000000e+01]),
#   'efobs': array([ 3.07379520e-04,  1.30477818e-04,  2.11404188e-04, -9.90000000e+01,
#           1.72833649e-05,  2.39994916e-05,  3.41811035e-05,  2.34734745e-05,
#           4.42102784e-05,  1.10708110e-04,  7.77447665e-05,  6.46651517e-05,
#           6.21661337e-05,  7.86302942e-05,  7.78669982e-05, -9.90000000e+01,
#           6.33760146e-05,  7.64483090e-05,  9.18024747e-05,  7.52719702e-05,
#           1.03525142e-04,  1.38563016e-04,  1.08507197e-04,  1.28717540e-04,
#           2.28389780e-04,  3.76773980e-03,  1.62392960e-03,  1.03275995e-02,
#           1.70071230e+00,  4.11118832e+00,  1.34789000e+00,  2.00057000e+00,
#           1.52229000e+00,  1.47698100e+00,  1.00000000e+10,  1.00000000e+10]),
#   'templ_radio': array([2.05074788e-07, 2.10124705e-07, 2.13468920e-07, ...,
#          8.21487434e-02, 8.73204723e-02, 9.28177908e-02])})

# %% [markdown]
# We can also fit the entire catalogue

# %%
n_obj = 30 #Number of objects to fit, leave blank to fit everything
n_proc = -1 #Number of threads to use, -1 for all available threads, 1 for serial mode
self.fit_catalogue(n_proc=n_proc,n_obj=n_obj)
# Out:
# Begin Multithreading
# 10 threads utilised
# 100%|██████████| 30/30 [00:17<00:00,  1.69it/s]
# /Users/takafumi/miniconda3/envs/py39/lib/python3.9/site-packages/stardust/main.py:1557: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mp_out=np.array(mp_out)
# Finished Fitting, Preparing Output..
# Time Elapsed: 24.94939374923706 s

# %% [markdown]
# Access outputs for each object

# %%
idx = 10
self.show_fit(idx)

#All the physical parameters like mstar, mdust and lir are contained within the self class
#These can be accessed like so
dust_mass = np.log10(self.mdust[idx])
e_dust_mass = self.e_mdust[idx]/self.mdust[idx]*np.log(10)**-1

print(r'Mstar: {:.2f} +- {:.2f}'.format(dust_mass,e_dust_mass))
# Out:
# Mstar: 8.34 +- 0.19

# %% [markdown]
# Alternatively, we can just look at the output table

# %%
self.tab
# Out:
# <Table length=300>
#    id        ra      dec   ...        chi2        nfilt      lastdet
#  int64    float32  float32 ...      float64       int64      float64
# -------- --------- ------- ... ------------------ ----- ------------------
# 10239543 149.62405 2.51671 ... 10.593182384983873    32 2164.5327562742236
# 10126383  150.3174 2.28307 ...  23.46307498834166    31  281.6324535701647
# 10253058 149.83897 2.67504 ... 154.69224090870327    33  633.4846059511304
# 10108428 150.00479 2.05551 ...  22.99707069946915    33  586.7845658640862
# 10041645 149.87355 1.60635 ...  7.194753592069906    30 1814.2726851568225
# 10227270 150.23978 2.71752 ...  32.78088139086863    33  610.4316189274788
# 10120472 150.07666 2.20598 ...  26.39293654459756    33  722.5882772560119
# 10094501 150.74622 2.34297 ...  7651.428850971455    33  528.1577595459521
# 10242336 149.37662 2.55059 ...  5.485561390378172    32  1286.165737356663
# 10262318 149.37788  2.8069 ...    8.6532791867612    32 1238.5807285003664
#      ...       ...     ... ...                ...   ...                ...
# 10018189 150.01204 1.65211 ...                0.0     0 1279.7668703136446
# 10209946 149.95259 2.51634 ...                0.0     0 432.99173407399655
# 10078348 150.62007 2.08543 ...                0.0     0 1302.6968532981873
# 10090834 150.48174 2.27319 ...                0.0     0 360.22247361151875
# 10006410  150.5789 1.82396 ...                0.0     0  644.9618854485751
# 10230464  150.1963 2.76542 ...                0.0     0 1015.0785768840313
# 10175241 149.60612 2.38721 ...                0.0     0  393.5321590575576
# 10121058 150.05661 2.20857 ...                0.0     0  416.7224495497942
# 10055434 149.85388 1.78401 ...                0.0     0            614.894
# 10005858  150.6141 1.80835 ...                0.0     0 1152.6535523719788

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,5))

plt.scatter(self.tab['mstar'],self.tab['sfr'],c=self.tab['z'],s=20,vmin=0,vmax=4,cmap='Spectral_r')
plt.colorbar(label='Redshift')
plt.loglog()
plt.xlim(1e8,)
plt.ylabel(r'SFR [M$_\odot$ yr$^{-1}$]')
plt.xlabel(r'$M_*$[M$_\odot$]')
plt.grid(alpha=.2)

# %%
self.set_ztemps()
# Out:
# Z_MIN, Z_MAX or Z_STEP parameters are not defined in config.
# Using default values (0.01,12,0.005)
# Redshift Templates Ready. Time Elapsed:24.23359489440918s
